# %% [markdown]
# ## Práctica 6
# Jeremy Rojas Mendoza 28/04/22

# %% [markdown]
# Vamos a cargar la primer imagen a color para poder pasarla del modelo RGB al modelo CMY.

# %%
from PIL import Image

# Open image, convert to CMYK and save as TIF
Image.open('Spider-Man.jpg').convert('CMYK').save('result.tif')

# %%
from PIL import Image

# Open image, convert to CMYK and save as TIF
Image.open('Spider-Man.jpg').convert('CMYK').save('result.jpg')

import cv2 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('result.jpg')

img_cmy = plt.imshow(image)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load image
bgr = cv2.imread('Spider-Man.jpg')

# Make float and divide by 255 to give BGRdash
bgrdash = bgr.astype(np.float)/255.

# Calculate K as (1 - whatever is biggest out of Rdash, Gdash, Bdash)
K = 1 - np.max(bgrdash, axis=2)

# Calculate C
C = (1-bgrdash[...,2] - K)/(1-K)

# Calculate M
M = (1-bgrdash[...,1] - K)/(1-K)

# Calculate Y
Y = (1-bgrdash[...,0] - K)/(1-K)

# Combine 4 channels into single image and re-scale back up to uint8
CMYK = (np.dstack((C,M,Y,K)) * 255).astype(np.uint8)

img_c = plt.imshow(C)
plt.show()
img_m = plt.imshow(M)
plt.show()
img_y = plt.imshow(Y)
plt.show()
img_k = plt.imshow(K)
plt.show()
# Out:
# /var/folders/vs/ffn7611s181fhlkyybd1pqlr0000gn/T/ipykernel_3842/1100518414.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bgrdash = bgr.astype(np.float)/255.
# /var/folders/vs/ffn7611s181fhlkyybd1pqlr0000gn/T/ipykernel_3842/1100518414.py:16: RuntimeWarning: invalid value encountered in true_divide
#   C = (1-bgrdash[...,2] - K)/(1-K)
# /var/folders/vs/ffn7611s181fhlkyybd1pqlr0000gn/T/ipykernel_3842/1100518414.py:19: RuntimeWarning: invalid value encountered in true_divide
#   M = (1-bgrdash[...,1] - K)/(1-K)
# /var/folders/vs/ffn7611s181fhlkyybd1pqlr0000gn/T/ipykernel_3842/1100518414.py:22: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
# Se supone que este es el bueno xd
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = cv2.imread('Spider-Man.jpg')
img_hsi = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
h, s, l = cv2.split(img_hsi)

plt.imshow(img_hsi)
plt.show()

plt.imshow(h)
plt.show()

plt.imshow(s)
plt.show()

plt.imshow(l)
plt.show()

# %%
plt.imshow(img_hsi)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Bibliografía
# https://stackoverflow.com/questions/23889620/is-there-any-other-way-to-convert-rgb-to-hsi
# https://www.codespeedy.com/splitting-rgb-and-hsv-values-in-an-image-using-opencv-python/
